# %% [raw]
# ---
# title: "Bayesian Optimisation fo Discrete Event Simulation Experiments"
# author: "Harry Newton"
# date: today
# execute:
#   echo: false
# format:
#   pdf:
#     documentclass: article
#     number-sections: true
# ---

# %%
EXP_FILE = "pilot_01_vihgp"

# %%
import torch
#Import Libaries
from pathlib import Path
import yaml
tkwargs = {
    "dtype": torch.double,# Datatype used by tensors
    "device": torch.device("cuda" if torch.cuda.is_available() else "cpu"), # Declares the 'device' location where the Tenosrs will be stored
}

#Plotting Libaries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %%
#Function for splitting flattened data
def split_macro_replications(train_flat, train_n, M, k, n, T):
	"""
	Splits flattened training data into:
		1. Initial design per macro (M, k*n, 1)
		2. Candidate data per macro as dictionary

	Args:
		train_flat: (N_total, 1) tensor
		train_n: (M, k+T) or (M, k+T, 1) tensor
		M: number of macro replications
		k: number of initial design points
		n: replications per initial design point
		T: number of BO iterations

	Returns:
		initial_data: (M, k*n, 1)
		candidates_dict: dict[m] -> list of tensors per iteration
	"""

    # सुनिश्चित correct shape
	if train_n.dim() == 3:
		train_n = train_n.squeeze(-1)

	initial_blocks = []
	candidates_dict = {}

	ptr = 0  # pointer into flattened tensor

	for m in range(M):
		# --- Initial design ---
		init_size = k * n
		init_block = train_flat[ptr: ptr + init_size]
		initial_blocks.append(init_block)
		ptr += init_size

        # --- Candidates ---
		candidates_dict[m] = []
        
        # for t in range(T):
        #     # number of reps at iteration t
        #     n_mt = int(train_n[m, k + t].item())

        #     if n_mt > 0:
        #         cand_block = train_flat[ptr: ptr + n_mt]
        #         candidates_dict[m].append(cand_block)
        #         ptr += n_mt
        #     else:
        #         candidates_dict[m].append(torch.empty(0, 1))
                
		for t in range(T):
			# number of reps at iteration t
			n_mt = int(train_n[m, k + t].item())

			if n_mt > 0:
				cand_block = train_flat[ptr: ptr + n_mt]
				candidates_dict[m].append(cand_block)
				ptr += n_mt
			else:
				candidates_dict[m].append(torch.empty(0, 1))
		candidates_dict[m] = torch.cat(candidates_dict[m]).flatten()

    # Stack initial data
	initial_data = torch.stack(initial_blocks)  # (M, k*n, 1)

	return initial_data, candidates_dict

# %%
""" 
This cell handles experimental paramaters, data and outptu
"""
def import_exp(exp_file):
	#Obtain Results Location and names
	config_loc = f"configs/{exp_file}.yml"

	with open(config_loc) as f:
		exp_params = yaml.safe_load(f)
	
	exp_name = exp_params['experiment_name']
	return exp_name,exp_params

def get_files(exp_name,dir_name,file_names,add=""):
	indir = Path(exp_name + f"/{dir_name}")

	data = {}
	for file_name in file_names:

		load_in = torch.load(indir /  f"{add}{file_name}.pt").to(**tkwargs)
		data[file_name] = load_in
	return data

##Import Experimental Paramaters
exp_file = EXP_FILE
exp_name,exp_params = import_exp(exp_file)

##Import Results for each of the models
all_data ={}
names = ['train_x','train_n','train_y','train_sigma2','x_strs','f_strs']

for m in exp_params['models']:

	all_data[m] = get_files(exp_name,"Data",names,add=f"{m}_")

##Import Test Data
names_test = ['test_x','test_y','test_sigma2']
test_data = get_files(exp_name,"Input",names_test)
test_data['optim_sol'] = exp_params['optim']


##Marshall out original dataset across replications (using any model as all use the same dataset)


gp_model = exp_params['GP']
k = exp_params['problem']['k']
M = exp_params['study']['M']
T = exp_params['study']['T']
n = exp_params['problem']['n']

train_n = all_data[m]['train_n'][:,:(k)]

if gp_model == "vihgp":
	cuttoff = k*n*M
	x_candidates = {}
	y_candidates = {}
	for m in exp_params['models']:
		#TODO Must cycle over all three models so remove have option to do train_x on last
		train_x, x_candidates[m] = split_macro_replications(all_data[m]['train_x'],
														all_data[m]['train_n'],
														M,
														k,
														n,
														T)
		train_y, y_candidates[m] = split_macro_replications(all_data[m]['train_y'],
														all_data[m]['train_n'],
														M,
														k,
														n,
														T)

		#Doesn't matter for this, all zero
		train_sigma2 = all_data[m]['train_sigma2'][:(cuttoff)].reshape((M,n*k,1))

else:	
	train_x = all_data[m]['train_x'][:,:(k)]
	train_y = all_data[m]['train_y'][:,:(k)]
	train_sigma2 = all_data[m]['train_sigma2'][:,:(k)]



##Make output file for analysis

outdir = Path(exp_name + "/Analysis")
outdir.mkdir(exist_ok=True)

# %%
iter = 1

test_x = test_data['test_x']
test_y = test_data['test_y']
test_sigma2 = test_data['test_sigma2']

fig, ax = plt.subplots(1,2,figsize=(12,4))
ax[0].plot(train_x[iter],train_y[iter], "x",color="r", label="Evaluations", alpha=0.5)

if exp_params['GP'] == "sk":
	ax[1].plot(train_x[iter],torch.sqrt(train_sigma2[iter]), "o",color="b", label="Empircal std", alpha=0.5)
ax[0].plot(test_x,test_y,color='g',label='$f(x)$')
ax[0].fill_between(
    test_x.squeeze(),
    test_y.squeeze() - 2 * torch.sqrt(test_sigma2).squeeze(),
    test_y.squeeze() + 2 * torch.sqrt(test_sigma2).squeeze(),
    color="C0",
    alpha=0.15,
    label="±2 $\\sigma_{\\varepsilon}(x)$",
)

ax[1].plot(test_x,test_y,color='g',label='$f(x)$')
ax[1].plot(test_x,torch.sqrt(test_sigma2),color='C0',label='$\\sigma_{\\varepsilon}(x)$')

ax[0].set_xlabel("$x$")
ax[0].set_ylabel("$y$")
ax[1].set_xlabel("$x$")
ax[1].set_ylabel("$y$")

ax[0].legend(loc="lower left")
ax[1].legend(loc="lower left")
#ax[1].set_title("Heteroscedastic regression")
fig.suptitle(f'Test Problem w/ evaluations for $m={iter}$')
testplot_loc = outdir / "test_problem.png"

# plt.savefig(testplot_loc ,bbox_inches="tight", dpi=200 )
# plt.close()

# %%
iter = 22
model = "IG"
test_x = test_data['test_x']
test_y = test_data['test_y']
test_sigma2 = test_data['test_sigma2']

model_num = len(exp_params['models'])

colours = ["C0", "C1", "C2", "C3"]

for macro in range(0,M):
	fig, ax = plt.subplots(model_num,1,figsize=(12,8))
	for i,m in enumerate(exp_params['models']):

		if gp_model == "vihgp":
			select_x = x_candidates[m]
			select_y = y_candidates[m]
		else:
			select_x = all_data[m]['train_x'][:,(k):]
			select_y = all_data[m]['train_y'][:,(k):]
			
		ax[i].plot(train_x[macro],train_y[macro], "x",color="r", label="Evaluations", alpha=0.5)
		ax[i].plot(select_x[macro],select_y[macro], "o",color=colours[i], label=f"Selected:{m}", alpha=0.5)
		ax[i].plot(test_x,test_y,color='g',label='$f(x)$')
		ax[i].fill_between(
				test_x.squeeze(),
				test_y.squeeze() - 2 * torch.sqrt(test_sigma2).squeeze(),
				test_y.squeeze() + 2 * torch.sqrt(test_sigma2).squeeze(),
				color="C0",
				alpha=0.15,
				label="±2 $\\sigma_{\\varepsilon}(x)$",
		)
		ax[i].set_xlabel("$x$")
		ax[i].set_ylabel("$y$")
		ax[i].legend(loc="lower left")


	ax[1].legend(loc="lower left")
	#ax[1].set_title("Heteroscedastic regression")
	fig.suptitle(f'Candidate selection w/ evaluations for $m={macro}$')
	candi_selec = outdir / f"candidate_selection_{macro}.png"

	plt.savefig(candi_selec ,bbox_inches="tight", dpi=200)
	plt.close()

# %%
""" 
In the future I want to compare function evaluations 
at the correct solution of the test function. To do so
I need to import test utils into analysis to get at the 
target function. I will do this later. For the moment
I will compare against seen fstars for each example

"""
from test_utils import Target_Function,get_k_inital_evals,NOISE_FUNCTION_DIAL,TEST_FUNCTION_DIAL,InverseLinearCostModel

test_function = Target_Function(test_function=TEST_FUNCTION_DIAL[exp_params['problem']["test_function_index"]],
																noise_function=NOISE_FUNCTION_DIAL[exp_params['problem']["noise_function_index"]],
																phi=exp_params['problem']['phi'],
																tau=exp_params['problem']['phi'],
															 )

cost_function = InverseLinearCostModel([exp_params['problem']['b1'],
										exp_params['problem']['b0']])

#TODO Import target function to calculate optimal values from maximisers
''' 
x axis: n replications used - total inital replcations

'''
for data in all_data.values():
		#Get noiseless test function values at predicted function maximisers
		data['f_strs_true'],_ = test_function.eval_target_true(data['x_strs'])
		
		#Get cummax of data
		data['f_strs_cummax'],_ = torch.cummax(data['f_strs_true'],dim=1) 
		
		#Get cost 
		#data['cost'] = 1/cost_function(data['train_n'][:,(k-1):])
		data['n'] = data['train_n'][...,(k-1):,:]
		# Get cummsum of replications used - inital
		sum = torch.cumsum(data['train_n'],dim=1)[:,(k-1):]
		normalised_sum = sum - sum[:,0].broadcast_to(sum.shape[:-1]).unsqueeze(-1)
		data['n_cumsum'] = normalised_sum

		# Get cumsum of costs used - inital
		#sum = torch.cumsum(data['cost'],dim=1)[:,(k-1):]
		#normalised_sum = sum - sum[:,0].broadcast_to(sum.shape[:-1]).unsqueeze(-1)
		#data['cost_cumsum'] = normalised_sum

# %%
#NOTE: Commented out for now, this way of displaying performance isn't very informative
# def interpolate_experiment(n_exp, f_exp, num_points=200,n_max=80):
#     """
#     n_exp, f_exp: tensors of shape [M, T, 1]
#     Returns:
#         n_grid: common x-grid
#         f_mean: mean interpolated f
#         f_std: std interpolated f
#     """
#     # convert to (M, T)
#     n = n_exp.squeeze(-1).cpu().numpy()
#     f = f_exp.squeeze(-1).cpu().numpy()
#     M, T = n.shape

#     # build common n-grid (min to max over *all* macroreplications)
#     n_min = n.min()
#     n_grid = np.linspace(n_min, n_max, num_points)

#     # store all interpolated curves
#     f_interp = np.zeros((M, num_points))

#     for i in range(M):
#         # Ensure n is strictly increasing (required for interpolation)
#         #order = np.argsort(n[i])
#         n_i = n[i]
#         f_i = f[i]

#         # interpolation function (linear)
#         f_fun = interp1d(n_i, f_i, kind="previous", fill_value="extrapolate")
#         f_interp[i] = f_fun(n_grid)

#     f_mean = f_interp.mean(axis=0)
#     f_std = f_interp.std(axis=0)

#     return n_grid, f_mean, f_std



# #Linear Interpolate and plot comparison 
# ##Interpolate uses linear interpolation
# #sns.set_theme(style="whitegrid", font_scale=1.4)
# fig, ax = plt.subplots(1,1,figsize=(10,5))
# M = exp_params['study']['M']
# for m in exp_params['models']:
     
# 	data = all_data[m]
# 	n_grid, f_mean,f_std = interpolate_experiment(data['n_cumsum'],data['f_strs_true'])
# 	ax.plot(n_grid, f_mean, label=m, linewidth=2.5)
# 	ax.fill_between(n_grid, f_mean - 2*f_std, f_mean + 2*f_std, alpha=0.2)

# ax.legend(loc="lower right")
# ax.set_xlabel("Cumulative $n$")
# ax.set_ylabel("$f^*$")
# ax.set_ylim(1.1,1.3)
# #NOTE
# ''' 
# f^* is currently the interpolated cumax across macroreplications of the 
# SK_model's predicted f^* at that point. 
# '''
# perfplot_loc = outdir / "performance_plot.png"
# fig.suptitle(f"Performance w/ $\pm 2\sigma$|$M=${M} Macroreplications|")
# plt.savefig(perfplot_loc ,bbox_inches="tight", dpi=200 )
# #plt.close()

# %%
import pandas as pd
import seaborn as sns

records = []

for m in exp_params['models']:
    data = all_data[m]
    
    # shape: [M, T, 1] → [M, T]
    values = data['f_strs_true'].squeeze(-1)
    
    for macro in range(values.shape[0]):
        for t in range(values.shape[1]):
            records.append({
                "model": m,
                "iteration": t,
                "value": values[macro, t].item(),
                "macro": macro
            })

df = pd.DataFrame(records)

# %%
# plt.figure(figsize=(10, 5))

# #--- Mean + confidence band ---
# # sns.lineplot(
# #     data=df,
# #     x="iteration",
# #     y="value",
# #     hue="model",
# #     #estimator="mean",
# #     errorbar=("ci", 95),
# #     linewidth=2,
# #     alpha=0.9
# # )
# sns.lineplot(
#     data=df,
#     x="iteration",
#     y="value",
#     hue="model",
#     estimator="mean",
#     errorbar=(("pi", 80)),
#     err_style="bars",     # ← switch from band → bars
#     err_kws={
#         "capsize": 3,
#         "elinewidth": 1,
#         #"alpha": 0.7
#     },
#     linewidth=2,
#     marker="o",
#     markersize=4
# )
# #--- Median overlay (visually distinct) ---
# sns.lineplot(
#     data=df,
#     x="iteration",
#     y="value",
#     hue="model",
#     estimator="median",
#     linestyle="--",      # dashed → distinct from mean
#     linewidth=1,       # slightly thicker
#     alpha=1.0,
#     legend=False,         # prevent duplicate legend entries
#     errorbar=None
# )

# # --- True optimum ---
# plt.axhline(
#     y=exp_params['optim'],
#     linestyle=':',
#     color='black',
#     linewidth=1.5,
#     label=r"$f^*$"
# )

# # --- Labels & styling ---
# plt.xlabel("Iteration $t$")
# plt.ylabel("Best value")
# plt.title(f"Best solution | M={M} | T={T}")

# plt.grid(alpha=0.3)

# # Clean legend (only models + optimum)
# handles, labels = plt.gca().get_legend_handles_labels()
# plt.legend(handles[:len(exp_params['models'])] + [handles[-1]],
#            labels[:len(exp_params['models'])] + [labels[-1]])

# #plt.savefig(outdir / "trace_plot_seaborn.png", dpi=200, bbox_inches="tight")

# %%
# plt.figure(figsize=(10, 5))

# # faint individual runs
# sns.lineplot(
#     data=df,
#     x="iteration",
#     y="value",
#     hue="model",
#     units="macro",
#     estimator=None,
#     alpha=0.15,
#     linewidth=1,
#     legend=False
# )

# # bold mean + CI
# sns.lineplot(
#     data=df,
#     x="iteration",
#     y="value",
#     hue="model",
#     estimator="mean",
#     errorbar=("ci", 95),
#     linewidth=2.5
# )

# %%
#NOTE: Plotting average true best against median
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

T = exp_params['study']['T']
M = exp_params['study']['M']
colours = ["C0", "C1", "C2", "C3"]

indep_varb = 'n_cumsum'
for i, m in enumerate(exp_params['models']):
	data = all_data[m]
	
	
	n_cumsum = data[indep_varb].mean(0)
	ncs_std_err = data[indep_varb].std(0)/np.sqrt(M)
	#f_strs_true = data['f_strs_true'][t]
	f_strs_true = data['f_strs_true'].mean(0)
	f_strs_median,_ = data['f_strs_true'].median(0)


	fst_std_err = data['f_strs_true'].std(0)/np.sqrt(M)
	fst_std_err = data['f_strs_true'].quantile(torch.tensor([0.1,0.9]).to(data['f_strs_true']),dim=0)
	ax.errorbar(
			n_cumsum.squeeze(-1),
			#torch.range(0,T),
			f_strs_true.squeeze(-1),
			#yerr=fst_std_err.squeeze(-1),
			xerr=ncs_std_err.squeeze(-1),
			color=colours[i],
			marker="o",          # show points
			linewidth=1.0,       # thinner line
			markersize=4,
			label=m 
	)
	ax.plot(
			n_cumsum.squeeze(-1),
			#torch.range(0,T),
		 	#f_strs_median.squeeze(-1),
			fst_std_err.squeeze(-1)[0],
			#label="median",
			label="10 prcnt",
			color=colours[i],
			linestyle='--',
		 )
	ax.plot(
			n_cumsum.squeeze(-1),
			#torch.range(0,T),
		 	#f_strs_median.squeeze(-1),
			fst_std_err.squeeze(-1)[1],
			#label="median",
			label="90 prcnt",
			color=colours[i],
			linestyle=':'
		 )
	# ax.plot(
	# 		n_cumsum.squeeze(-1),
	# 		#torch.range(0,T),
	# 	 	f_strs_median.squeeze(-1),
	# 		label="median",
	# 		color=colours[i],
	# 	 )
ax.hlines(y=exp_params['optim'],xmin=0,xmax=80,color='r',linestyles='--',label="$f^*$",alpha=0.2)
ax.legend(loc="lower right")
ax.set_xlabel("Average Cumulative $n$")
#ax.set_xlabel("Iteration $t$")
ax.set_ylabel("$f^*$")
ax.set_ylim(1.2,1.25)
best_loc = outdir / "trace_plot.png"
fig.suptitle(f"Avg True Best solution|$M=${M} Macroreplications|$T=${T} BO Iterations")
plt.savefig(best_loc ,bbox_inches="tight", dpi=200 )
#plt.close()

# %%
# plt.hist(all_data['IG']['f_strs_true'][:,5])
# all_data['IG']['f_strs_true'][:,7]

# %%
# print(all_data['IG']['f_strs_true'][:,7].mean())
# print(all_data['IG']['f_strs_true'][:,7].quantile(torch.tensor([0.1]).to(all_data['IG']['f_strs_true'][:,7])))

# %%
#NOTE: Plotting average true best against median
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

T = exp_params['study']['T']
M = exp_params['study']['M']
colours = ["C0", "C1", "C2", "C3"]

indep_varb = 'n'
for i, m in enumerate(exp_params['models']):
	data = all_data[m]
  
	n_cumsum = data[indep_varb].mean(0)
	ncs_std_err = data[indep_varb].std(0)/np.sqrt(M)

	ax.errorbar(
			#n_cumsum.squeeze(-1),
			torch.arange(0,T+1),
			n_cumsum.squeeze(-1),
			yerr=ncs_std_err.squeeze(-1),
			color=colours[i],
			marker="o",          # show points
			linewidth=1.0,       # thinner line
			markersize=4,
			label=m 
	)
	
#ax.hlines(y=exp_params['optim'],xmin=0,xmax=T,color='r',linestyles='--',label="$f^*$")
ax.legend(loc="lower right")
#ax.set_xlabel("Cumulative $n$")
ax.set_xlabel("Iteration $t$")
ax.set_ylabel("Average $n$")

repplot_loc = outdir / "rep_trace_plot.png"
fig.suptitle(f"Average Reps per iter |$M=${M}|$T=${T}")
plt.savefig(repplot_loc ,bbox_inches="tight", dpi=200 )
plt.close()

# %%
from IPython.display import Markdown, display # Included for automation
from test_utils import TEST_FUNCTION_NAMES, NOISE_FUNCTION_NAMES

""" 
Below will be a convinient summary section 
for the named experiment at the top. To be inlcuded:
- Paramaters used

Text No Longer Used:
All three experiments began with $k$ equally spaced intial values. Each was sampled $n$ times 
to produce a mean evaluation $y$ with variance $\\sigma_{{\\varepsilon}}$. Each data point can be summarised by the set $(x,n,y,\\sigma_{{\\varepsilon}})$.
Each experiment was run over $M$ macroreplications and each BO instance was run over $T$ iterations.
The table bellow shows the values used for this experiment:

"""
gp_names = {"sk": "SK-HGP",
            "vihgp":"VI-HGP"}
gp_used = exp_params['GP']

report_md = f"""
# Experiment: {exp_name}
In this experiment we compare the performance between three configurations:

- *Vanilla*: {gp_names[gp_used]} GP with Expected Improvement 
- *AEI*: {gp_names[gp_used]} with Augmented Expected Improvement
- *IG* {gp_names[gp_used]} with Information Gain

All three experiments began with $k$ equally spaced intial values. Each was sampled $n$ times 
to produce a dataset $\\mathcal{{D}} = (x_i,y_i)_{{i=1}}^{{k \\times n}}$. Each data point can be summarised by the set $(x,n,y)$.
Each experiment was run over $M$ macroreplications and each BO instance was run over $T$ iterations. If Vanilla configuration has 
been included in these experiments it has no replication aware acquisition function, so $n_v$ replications are sampled
every iteration.
The table bellow shows the values used for this experiment:

| Paramater | Value |
|--------|-------|
| $k$ | {exp_params['problem']['k']} |
| $M$ | {exp_params['study']['M']} |
| $T$ | {exp_params['study']['T']} |
| $n$ | {exp_params['problem']['n']} |
| $n_v$ | {exp_params['problem']['n_v']} |
| seed| {exp_params['problem']['seed']} |

: Experimental paramaters.


## Test Problem

The test function for this experiment is defined as:
$$
{TEST_FUNCTION_NAMES[exp_params['problem']["test_function_index"]]}. 
$$
And the noise function is defined as:
$$
{NOISE_FUNCTION_NAMES[exp_params['problem']["noise_function_index"]]}
$$\n
The paramatarisation of the noise function, the $x$ and $n$ domains can be found in the table below.

| Paramater | Value |
|--------|-------|
| x | $[{exp_params['problem']['x_min']:.0f},{exp_params['problem']['x_max']:.0f}]$ |
| n | $[{exp_params['problem']['n_min']:.0f},{exp_params['problem']['n_max']:.0f}]$ |
| $\\phi$ | {exp_params['problem']['phi']} |
| $\\tau$ | {exp_params['problem']['tau']} |

: Test Problem paramater values and domain. Replication domain is also included

![Test problem to be optimised with the true signal and noise functions present. Initial evaluations for $m={iter}$ are also present]({testplot_loc})\n

The cost function is the inverse linear function
$$
c(n) = \\frac{{1}}{{ \\beta_0 + \\beta_1 n}}
$$

| Paramater | Value |
|--------|-------|
| $\\beta_0$ | ${exp_params['problem']['b0']}$ |
| $\\beta_1$ | ${exp_params['problem']['b1']}$ |

: Cost function paramaters.
"""

vihgp = f"""
## Variational Paramaters
| Paramater | Value |
|--------|-------|
| iters | ${exp_params['misc']['vihgp']['iters']:.0f}$ |
| n_u | ${exp_params['misc']['vihgp']['n_u']:.0f}$ |

: This table includes the number of iterations used to fit the VI-HGP and the number of inducing points used - $n_u$.
"""

if exp_params['GP'] == "vihgp":
    report_md = report_md + vihgp



display(Markdown(report_md))
# Out:
# # Experiment: Pilot_01 VIHGP
# In this experiment we compare the performance between three configurations:
#
# - *Vanilla*: VI-HGP GP with Expected Improvement
# - *AEI*: VI-HGP with Augmented Expected Improvement
# - *IG* VI-HGP with Information Gain
#
# All three experiments began with $k$ equally spaced intial values. Each was sampled $n$ times
# to produce a dataset $\mathcal{D} = (x_i,y_i)_{i=1}^{k \times n}$. Each data point can be summarised by the set $(x,n,y)$.
# Each experiment was run over $M$ macroreplications and each BO instance was run over $T$ iterations. If Vanilla configuration has
# been included in these experiments it has no replication aware acquisition function, so $n_v$ replications are sampled
# every iteration.
# The table bellow shows the values used for this experiment:
#
# | Paramater | Value |
# |--------|-------|
# | $k$ | 50 |
# | $M$ | 25 |
# | $T$ | 10 |
# | $n$ | 1 |
# | $n_v$ | 5 |
# | seed| 12345 |
#
# : Experimental paramaters.
#
#
# ...

# %% [markdown]
# ## Results
#
# In the results section below I compare the performance between the three configurations: vanilla, IG and AEI.
#
# A basic indicator of performance is the effectiveness of a configuration in finding the optimal point with minimal expenditure of resources. Here we plot the average cumulative sum of $\mathbf{\hat{n}}$, which is the average replication selection path over $M=25$ macroreplications for each iteration, against the average true maximum $f^*$- the best recorded $f^*$ up to a given BO iteration $t$. The $\mathbf{\hat{x}}^{*}=[x^*_1,\dots,x^*_T]$  sequence is the GP model's predicted maximiser of the test function $f$ for each iteration $t$, then the predicted optimal solutions can by found by inputting these values into the test function $\mathbf{\hat{f}}^* = f(\mathbf{\hat{x}}^{*})$.
#
# In the section below are two plots (1) The average true best solution against cumulative number of replications. Also included in this plot are the 10th (dashed line) as well as the 90th (dotted line) percentiles, and the true optimal value $f^*$.(2) The average number of replications spent per iteration.

# %%
display(Markdown(f"![Performance Comparison between models across {M} macroreplications using the maximum predicted solution. This is calculated using the predicted maximiser and the true, noiseless test function.]({best_loc}){{#comp-plot}}"))
# Out:
# ![Performance Comparison between models across 25 macroreplications using the maximum predicted solution. This is calculated using the predicted maximiser and the true, noiseless test function.](Pilot_01 VIHGP/Analysis/trace_plot.png){#comp-plot}

# %%
display(Markdown(f"![Average 'number of replications' $n$ selected pre iteration. Compared over models]({repplot_loc}){{#rep-comp-plot}}"))
# Out:
# ![Average 'number of replications' $n$ selected pre iteration. Compared over models](Pilot_01 VIHGP/Analysis/rep_trace_plot.png){#rep-comp-plot}
